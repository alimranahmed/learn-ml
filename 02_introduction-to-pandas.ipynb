# %%
import pandas as pd

# %% [markdown]
# ## 2 main datatypes

# %%
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1 dimentional

# %%
colours = pd.Series(["Red", "Blue", "White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# DataFrame = 2 dimentional
car_data = pd.DataFrame({"Car make": series, "Colour": colours})
car_data
# Out:
#   Car make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %% [markdown]
# ## Impor/Export Data

# %%
# Import data
car_sales = pd.read_csv("car_sales.csv")

# %%
car_sales
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW    4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3           Audi   23000.0  crossover      240      4.2      Petrol
# 4         Toyota   18300.0  crossover      120      2.0      Petrol
# 5  Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 6            BMW    6100.0      sedan      438      2.0         Gas
# 7           Audi   14200.0      vagon      200      2.7      Diesel
# 8        Renault   10799.0      vagon      193      1.5      Diesel
# 9     Volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7
# 4          yes  2011         Rav 4
# ...

# %%
# Exporting a dataframe
car_sales.to_csv("exported_car_sales.csv", index = False)

# %%
exported_car_sales = pd.read_csv("exported_car_sales.csv")
exported_car_sales
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW    4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3           Audi   23000.0  crossover      240      4.2      Petrol
# 4         Toyota   18300.0  crossover      120      2.0      Petrol
# 5  Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 6            BMW    6100.0      sedan      438      2.0         Gas
# 7           Audi   14200.0      vagon      200      2.7      Diesel
# 8        Renault   10799.0      vagon      193      1.5      Diesel
# 9     Volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7
# 4          yes  2011         Rav 4
# ...

# %% [markdown]
# ## Describe data

# %%
# Attribute
car_sales.dtypes

# Function
# car_sales.to_csv()
# Out:
# Brand            object
# Price           float64
# Body             object
# Mileage           int64
# EngineV         float64
# Engine Type      object
# Registration     object
# Year              int64
# Model            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Brand', 'Price', 'Body', 'Mileage', 'EngineV', 'Engine Type',
#        'Registration', 'Year', 'Model'],
#       dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Brand', 'Price', 'Body', 'Mileage', 'EngineV', 'Engine Type',
#        'Registration', 'Year', 'Model'],
#       dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#                Price     Mileage    EngineV         Year
# count      10.000000   10.000000  10.000000    10.000000
# mean    29919.800000  246.500000   2.960000  2004.100000
# std     60116.474061  135.661548   1.432325     7.738073
# min      1400.000000    0.000000   1.500000  1991.000000
# 25%      6550.000000  194.750000   2.000000  1999.000000
# 50%     12049.500000  226.000000   2.350000  2004.500000
# 75%     17275.000000  337.750000   3.875000  2010.000000
# max    199999.000000  438.000000   5.500000  2016.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         10 non-null     object
#  1   Price         10 non-null     float64
#  2   Body          10 non-null     object
#  3   Mileage       10 non-null     int64
#  4   EngineV       10 non-null     float64
#  5   Engine Type   10 non-null     object
#  6   Registration  10 non-null     object
#  7   Year          10 non-null     int64
#  8   Model         10 non-null     object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 852.0+ bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Price      29919.80
# Mileage      246.50
# EngineV        2.96
# Year        2004.10
# dtype: float64

# %%
# Calculate any mean
car_prices = pd.Series([3000, 1500, 110505])
car_prices.mean()
# Out:
# 38335.0

# %%
car_sales["Price"].sum()
# Out:
# 299198.0

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head()
# Out:
#            Brand    Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW   4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz   7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz  13300.0      sedan      358      5.0         Gas
# 3           Audi  23000.0  crossover      240      4.2      Petrol
# 4         Toyota  18300.0  crossover      120      2.0      Petrol
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7
# 4          yes  2011         Rav 4

# %%
car_sales.head(10)
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW    4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3           Audi   23000.0  crossover      240      4.2      Petrol
# 4         Toyota   18300.0  crossover      120      2.0      Petrol
# 5  Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 6            BMW    6100.0      sedan      438      2.0         Gas
# 7           Audi   14200.0      vagon      200      2.7      Diesel
# 8        Renault   10799.0      vagon      193      1.5      Diesel
# 9     Volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7
# 4          yes  2011         Rav 4
# ...

# %%
car_sales.tail()
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 5  Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 6            BMW    6100.0      sedan      438      2.0         Gas
# 7           Audi   14200.0      vagon      200      2.7      Diesel
# 8        Renault   10799.0      vagon      193      1.5      Diesel
# 9     Volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration  Year    Model
# 5          yes  2016   GLS 63
# 6          yes  1997      320
# 7          yes  2006       A6
# 8          yes  2012   Megane
# 9           no  1999  Golf IV

# %%
# .lock & .iloc
animals = pd.Series(["cat", "dogs", "bird", "panda", "snake"],
                  index = [0, 3, 9, 8, 3])

# %%
animals
# Out:
# 0      cat
# 3     dogs
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
#.lock refers to index
animals.loc[3]
# Out:
# 3     dogs
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales.loc[3]
# Out:
# Brand                Audi
# Price             23000.0
# Body            crossover
# Mileage               240
# EngineV               4.2
# Engine Type        Petrol
# Registration          yes
# Year                 2007
# Model                  Q7
# Name: 3, dtype: object

# %%
# .iloc refers to position
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales.iloc[3]
# Out:
# Brand                Audi
# Price             23000.0
# Body            crossover
# Mileage               240
# EngineV               4.2
# Engine Type        Petrol
# Registration          yes
# Year                 2007
# Model                  Q7
# Name: 3, dtype: object

# %%
car_sales.head()
# Out:
#            Brand    Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW   4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz   7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz  13300.0      sedan      358      5.0         Gas
# 3           Audi  23000.0  crossover      240      4.2      Petrol
# 4         Toyota  18300.0  crossover      120      2.0      Petrol
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7
# 4          yes  2011         Rav 4

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3    dogs
# 9    bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#            Brand    Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW   4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz   7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz  13300.0      sedan      358      5.0         Gas
# 3           Audi  23000.0  crossover      240      4.2      Petrol
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7

# %%
car_sales["Brand"]
# Out:
# 0              BMW
# 1    Mercedes-Benz
# 2    Mercedes-Benz
# 3             Audi
# 4           Toyota
# 5    Mercedes-Benz
# 6              BMW
# 7             Audi
# 8          Renault
# 9       Volkswagen
# Name: Brand, dtype: object

# %%
car_sales.Brand
# Out:
# 0              BMW
# 1    Mercedes-Benz
# 2    Mercedes-Benz
# 3             Audi
# 4           Toyota
# 5    Mercedes-Benz
# 6              BMW
# 7             Audi
# 8          Renault
# 9       Volkswagen
# Name: Brand, dtype: object

# %%
car_sales["Engine Type"]
# Out:
# 0    Petrol
# 1    Diesel
# 2       Gas
# 3    Petrol
# 4    Petrol
# 5    Petrol
# 6       Gas
# 7    Diesel
# 8    Diesel
# 9       Gas
# Name: Engine Type, dtype: object

# %%
car_sales[car_sales["Brand"] == "BMW"]
# Out:
#   Brand   Price   Body  Mileage  EngineV Engine Type Registration  Year Model
# 0   BMW  4200.0  sedan      277      2.0      Petrol          yes  1991   320
# 6   BMW  6100.0  sedan      438      2.0         Gas          yes  1997   320

# %%
car_sales[car_sales["Year"] > 2010]
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 4         Toyota   18300.0  crossover      120      2.0      Petrol
# 5  Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 8        Renault   10799.0      vagon      193      1.5      Diesel
#
#   Registration  Year   Model
# 4          yes  2011   Rav 4
# 5          yes  2016  GLS 63
# 8          yes  2012  Megane

# %%
car_sales[car_sales["Year"] > 2015]
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 5  Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
#
#   Registration  Year   Model
# 5          yes  2016  GLS 63

# %%
pd.crosstab(car_sales["Brand"], car_sales["Body"])
# Out:
# Body           crossover  other  sedan  vagon  van
# Brand
# Audi                   1      0      0      1    0
# BMW                    0      0      2      0    0
# Mercedes-Benz          1      0      1      0    1
# Renault                0      0      0      1    0
# Toyota                 1      0      0      0    0
# Volkswagen             0      1      0      0    0

# %%
# group by
car_sales.groupby(["Brand"]).mean("Price")
# Out:
#                  Price     Mileage   EngineV    Year
# Brand
# Audi           18600.0  220.000000  3.450000  2006.5
# BMW             5150.0  357.500000  2.000000  1994.0
# Mercedes-Benz  73733.0  261.666667  4.466667  2006.0
# Renault        10799.0  193.000000  1.500000  2012.0
# Toyota         18300.0  120.000000  2.000000  2011.0
# Volkswagen      1400.0  212.000000  1.800000  1999.0

# %%
# if plot is not showing up run the following line
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Mileage"].plot()
# Out:
# <Axes: >

# %%
car_sales["Year"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Mainpulating Data

# %%
car_sales["Brand"].str.lower()
# Out:
# 0              bmw
# 1    mercedes-benz
# 2    mercedes-benz
# 3             audi
# 4           toyota
# 5    mercedes-benz
# 6              bmw
# 7             audi
# 8          renault
# 9       volkswagen
# Name: Brand, dtype: object

# %%
car_sales
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW    4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3           Audi   23000.0  crossover      240      4.2      Petrol
# 4         Toyota   18300.0  crossover      120      2.0      Petrol
# 5  Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 6            BMW    6100.0      sedan      438      2.0         Gas
# 7           Audi   14200.0      vagon      200      2.7      Diesel
# 8        Renault   10799.0      vagon      193      1.5      Diesel
# 9     Volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7
# 4          yes  2011         Rav 4
# ...

# %%
car_sales["Brand"] = car_sales["Brand"].str.lower()

# %%
car_sales
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            bmw    4200.0      sedan      277      2.0      Petrol
# 1  mercedes-benz    7900.0        van      427      2.9      Diesel
# 2  mercedes-benz   13300.0      sedan      358      5.0         Gas
# 3           audi   23000.0  crossover      240      4.2      Petrol
# 4         toyota   18300.0  crossover      120      2.0      Petrol
# 5  mercedes-benz  199999.0  crossover        0      5.5      Petrol
# 6            bmw    6100.0      sedan      438      2.0         Gas
# 7           audi   14200.0      vagon      200      2.7      Diesel
# 8        renault   10799.0      vagon      193      1.5      Diesel
# 9     volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7
# 4          yes  2011         Rav 4
# ...

# %%
car_sales_missing = pd.read_csv("car_sales_with_missing_data.csv")

# %%
car_sales_missing
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            NaN    4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3            NaN   23000.0  crossover      240      4.2      Petrol
# 4         Toyota       NaN  crossover      120      2.0      Petrol
# 5  Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 6            BMW    6100.0      sedan      438      2.0         Gas
# 7           Audi       NaN      vagon      200      2.7      Diesel
# 8        Renault       NaN      vagon      193      1.5      Diesel
# 9     Volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration    Year         Model
# 0          yes  1991.0           320
# 1          yes  1999.0  Sprinter 212
# 2          yes  2003.0         S 500
# 3          yes  2007.0            Q7
# ...

# %%
car_sales_missing["Price"].fillna(car_sales_missing["Price"].mean())
# Out:
# 0      4200.0
# 1      7900.0
# 2     13300.0
# 3     23000.0
# 4     36557.0
# 5    199999.0
# 6      6100.0
# 7     36557.0
# 8     36557.0
# 9      1400.0
# Name: Price, dtype: float64

# %%
car_sales_missing
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            NaN    4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3            NaN   23000.0  crossover      240      4.2      Petrol
# 4         Toyota       NaN  crossover      120      2.0      Petrol
# 5  Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 6            BMW    6100.0      sedan      438      2.0         Gas
# 7           Audi       NaN      vagon      200      2.7      Diesel
# 8        Renault       NaN      vagon      193      1.5      Diesel
# 9     Volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration    Year         Model
# 0          yes  1991.0           320
# 1          yes  1999.0  Sprinter 212
# 2          yes  2003.0         S 500
# 3          yes  2007.0            Q7
# ...

# %%
car_sales_missing["Price"].fillna(car_sales_missing["Price"].mean(),
                                 inplace=True)

# %%
car_sales_missing.head(15)
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            NaN    4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3            NaN   23000.0  crossover      240      4.2      Petrol
# 4         Toyota   36557.0  crossover      120      2.0      Petrol
# 5  Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 6            BMW    6100.0      sedan      438      2.0         Gas
# 7           Audi   36557.0      vagon      200      2.7      Diesel
# 8        Renault   36557.0      vagon      193      1.5      Diesel
# 9     Volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration    Year         Model
# 0          yes  1991.0           320
# 1          yes  1999.0  Sprinter 212
# 2          yes  2003.0         S 500
# 3          yes  2007.0            Q7
# ...

# %%
car_sales_missing.head(15)
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            NaN    4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3            NaN   23000.0  crossover      240      4.2      Petrol
# 4         Toyota   36557.0  crossover      120      2.0      Petrol
# 5  Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 6            BMW    6100.0      sedan      438      2.0         Gas
# 7           Audi   36557.0      vagon      200      2.7      Diesel
# 8        Renault   36557.0      vagon      193      1.5      Diesel
# 9     Volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration    Year         Model
# 0          yes  1991.0           320
# 1          yes  1999.0  Sprinter 212
# 2          yes  2003.0         S 500
# 3          yes  2007.0            Q7
# ...

# %%
car_sales_missing.dropna()
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 1  Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 4         Toyota   36557.0  crossover      120      2.0      Petrol
# 5  Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 7           Audi   36557.0      vagon      200      2.7      Diesel
# 8        Renault   36557.0      vagon      193      1.5      Diesel
# 9     Volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration    Year         Model
# 1          yes  1999.0  Sprinter 212
# 2          yes  2003.0         S 500
# 4          yes  2011.0         Rav 4
# 5          yes  2016.0        GLS 63
# 7          yes  2006.0            A6
# 8          yes  2012.0        Megane
# 9           no  1999.0       Golf IV

# %%
car_sales_missing.head(15)
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            NaN    4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3            NaN   23000.0  crossover      240      4.2      Petrol
# 4         Toyota   36557.0  crossover      120      2.0      Petrol
# 5  Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 6            BMW    6100.0      sedan      438      2.0         Gas
# 7           Audi   36557.0      vagon      200      2.7      Diesel
# 8        Renault   36557.0      vagon      193      1.5      Diesel
# 9     Volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration    Year         Model
# 0          yes  1991.0           320
# 1          yes  1999.0  Sprinter 212
# 2          yes  2003.0         S 500
# 3          yes  2007.0            Q7
# ...

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing.head(15)
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 1  Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 4         Toyota   36557.0  crossover      120      2.0      Petrol
# 5  Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 7           Audi   36557.0      vagon      200      2.7      Diesel
# 8        Renault   36557.0      vagon      193      1.5      Diesel
# 9     Volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration    Year         Model
# 1          yes  1999.0  Sprinter 212
# 2          yes  2003.0         S 500
# 4          yes  2011.0         Rav 4
# 5          yes  2016.0        GLS 63
# 7          yes  2006.0            A6
# 8          yes  2012.0        Megane
# 9           no  1999.0       Golf IV

# %%
# Column from series
seats_column = pd.Series([5, 5, 5, 5, 5])

# New calumn called seats
car_sales["Seats"] = seats_column

# %%
car_sales.head(15)
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            bmw    4200.0      sedan      277      2.0      Petrol
# 1  mercedes-benz    7900.0        van      427      2.9      Diesel
# 2  mercedes-benz   13300.0      sedan      358      5.0         Gas
# 3           audi   23000.0  crossover      240      4.2      Petrol
# 4         toyota   18300.0  crossover      120      2.0      Petrol
# 5  mercedes-benz  199999.0  crossover        0      5.5      Petrol
# 6            bmw    6100.0      sedan      438      2.0         Gas
# 7           audi   14200.0      vagon      200      2.7      Diesel
# 8        renault   10799.0      vagon      193      1.5      Diesel
# 9     volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration  Year         Model  Seats
# 0          yes  1991           320    5.0
# 1          yes  1999  Sprinter 212    5.0
# 2          yes  2003         S 500    5.0
# 3          yes  2007            Q7    5.0
# ...

# %%
car_sales["Seats"].fillna(5, inplace=True)

# %%
car_sales.head(15)
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            bmw    4200.0      sedan      277      2.0      Petrol
# 1  mercedes-benz    7900.0        van      427      2.9      Diesel
# 2  mercedes-benz   13300.0      sedan      358      5.0         Gas
# 3           audi   23000.0  crossover      240      4.2      Petrol
# 4         toyota   18300.0  crossover      120      2.0      Petrol
# 5  mercedes-benz  199999.0  crossover        0      5.5      Petrol
# 6            bmw    6100.0      sedan      438      2.0         Gas
# 7           audi   14200.0      vagon      200      2.7      Diesel
# 8        renault   10799.0      vagon      193      1.5      Diesel
# 9     volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration  Year         Model  Seats
# 0          yes  1991           320    5.0
# 1          yes  1999  Sprinter 212    5.0
# 2          yes  2003         S 500    5.0
# 3          yes  2007            Q7    5.0
# ...

# %%
# Column from Python list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 5.6, 8.2, 3.9, 4.7, 6.3, 7.5]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# If we want to create from Python list 
# the length of list should be same as the number of rows 
# of dataframe
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            bmw    4200.0      sedan      277      2.0      Petrol
# 1  mercedes-benz    7900.0        van      427      2.9      Diesel
# 2  mercedes-benz   13300.0      sedan      358      5.0         Gas
# 3           audi   23000.0  crossover      240      4.2      Petrol
# 4         toyota   18300.0  crossover      120      2.0      Petrol
# 5  mercedes-benz  199999.0  crossover        0      5.5      Petrol
# 6            bmw    6100.0      sedan      438      2.0         Gas
# 7           audi   14200.0      vagon      200      2.7      Diesel
# 8        renault   10799.0      vagon      193      1.5      Diesel
# 9     volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration  Year         Model  Seats  Fuel per 100KM
# 0          yes  1991           320    5.0             7.5
# 1          yes  1999  Sprinter 212    5.0             9.2
# ...

# %%
car_sales["Fuel per 100KM"] = pd.Series([7.5, 9.2, 5.0, 9.6])
car_sales
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            bmw    4200.0      sedan      277      2.0      Petrol
# 1  mercedes-benz    7900.0        van      427      2.9      Diesel
# 2  mercedes-benz   13300.0      sedan      358      5.0         Gas
# 3           audi   23000.0  crossover      240      4.2      Petrol
# 4         toyota   18300.0  crossover      120      2.0      Petrol
# 5  mercedes-benz  199999.0  crossover        0      5.5      Petrol
# 6            bmw    6100.0      sedan      438      2.0         Gas
# 7           audi   14200.0      vagon      200      2.7      Diesel
# 8        renault   10799.0      vagon      193      1.5      Diesel
# 9     volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration  Year         Model  Seats  Fuel per 100KM
# 0          yes  1991           320    5.0             7.5
# 1          yes  1999  Sprinter 212    5.0             9.2
# ...

# %%
car_sales["Number of wheels"] = 4

# %%
car_sales
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            bmw    4200.0      sedan      277      2.0      Petrol
# 1  mercedes-benz    7900.0        van      427      2.9      Diesel
# 2  mercedes-benz   13300.0      sedan      358      5.0         Gas
# 3           audi   23000.0  crossover      240      4.2      Petrol
# 4         toyota   18300.0  crossover      120      2.0      Petrol
# 5  mercedes-benz  199999.0  crossover        0      5.5      Petrol
# 6            bmw    6100.0      sedan      438      2.0         Gas
# 7           audi   14200.0      vagon      200      2.7      Diesel
# 8        renault   10799.0      vagon      193      1.5      Diesel
# 9     volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration  Year         Model  Seats  Fuel per 100KM  Number of wheels
# 0          yes  1991           320    5.0             7.5                 4
# ...

# %%
car_sales["Passed road safety"] = True

# %%
car_sales.dtypes
# Out:
# Brand                  object
# Price                 float64
# Body                   object
# Mileage                 int64
# EngineV               float64
# Engine Type            object
# Registration           object
# Year                    int64
# Model                  object
# Seats                 float64
# Fuel per 100KM        float64
# Number of wheels        int64
# Passed road safety       bool
# dtype: object

# %%
car_sales = car_sales.drop("Fuel per 100KM", axis = 1) # axis = 1 means column

# %%
car_sales
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            bmw    4200.0      sedan      277      2.0      Petrol
# 1  mercedes-benz    7900.0        van      427      2.9      Diesel
# 2  mercedes-benz   13300.0      sedan      358      5.0         Gas
# 3           audi   23000.0  crossover      240      4.2      Petrol
# 4         toyota   18300.0  crossover      120      2.0      Petrol
# 5  mercedes-benz  199999.0  crossover        0      5.5      Petrol
# 6            bmw    6100.0      sedan      438      2.0         Gas
# 7           audi   14200.0      vagon      200      2.7      Diesel
# 8        renault   10799.0      vagon      193      1.5      Diesel
# 9     volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration  Year         Model  Seats  Number of wheels  \
# 0          yes  1991           320    5.0                 4
# 1          yes  1999  Sprinter 212    5.0                 4
# ...

# %%
car_sales_shuffled = car_sales.sample(frac = 1)

# %%
car_sales_shuffled
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW    4200.0      sedan      277      2.0      Petrol
# 5  Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 7           Audi   14200.0      vagon      200      2.7      Diesel
# 3           Audi   23000.0  crossover      240      4.2      Petrol
# 1  Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 4         Toyota   18300.0  crossover      120      2.0      Petrol
# 9     Volkswagen    1400.0      other      212      1.8         Gas
# 6            BMW    6100.0      sedan      438      2.0         Gas
# 2  Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 8        Renault   10799.0      vagon      193      1.5      Diesel
#
#   Registration  Year         Model
# 0          yes  1991           320
# 5          yes  2016        GLS 63
# 7          yes  2006            A6
# 3          yes  2007            Q7
# 1          yes  1999  Sprinter 212
# ...

# %%
# oly select 20% of data
car_sales_shuffled.sample(frac = 0.2)
# Out:
#   Brand    Price       Body  Mileage  EngineV Engine Type Registration  Year  \
# 3  Audi  23000.0  crossover      240      4.2      Petrol          yes  2007
# 6   BMW   6100.0      sedan      438      2.0         Gas          yes  1997
#
#   Model
# 3    Q7
# 6   320

# %%
car_sales_shuffled.reset_index(inplace = True, drop = True)

# %%
car_sales_shuffled
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW    4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 2           Audi   14200.0      vagon      200      2.7      Diesel
# 3           Audi   23000.0  crossover      240      4.2      Petrol
# 4  Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 5         Toyota   18300.0  crossover      120      2.0      Petrol
# 6     Volkswagen    1400.0      other      212      1.8         Gas
# 7            BMW    6100.0      sedan      438      2.0         Gas
# 8  Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 9        Renault   10799.0      vagon      193      1.5      Diesel
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  2016        GLS 63
# 2          yes  2006            A6
# 3          yes  2007            Q7
# 4          yes  1999  Sprinter 212
# ...

# %%
car_sales
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW    4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3           Audi   23000.0  crossover      240      4.2      Petrol
# 4         Toyota   18300.0  crossover      120      2.0      Petrol
# 5  Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 6            BMW    6100.0      sedan      438      2.0         Gas
# 7           Audi   14200.0      vagon      200      2.7      Diesel
# 8        Renault   10799.0      vagon      193      1.5      Diesel
# 9     Volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7
# 4          yes  2011         Rav 4
# ...

# %%
car_sales["Mileage"] = car_sales["Mileage"].apply(lambda x: x / 1.6)

# %%
car_sales
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW    4200.0      sedan  173.125      2.0      Petrol
# 1  Mercedes-Benz    7900.0        van  266.875      2.9      Diesel
# 2  Mercedes-Benz   13300.0      sedan  223.750      5.0         Gas
# 3           Audi   23000.0  crossover  150.000      4.2      Petrol
# 4         Toyota   18300.0  crossover   75.000      2.0      Petrol
# 5  Mercedes-Benz  199999.0  crossover    0.000      5.5      Petrol
# 6            BMW    6100.0      sedan  273.750      2.0         Gas
# 7           Audi   14200.0      vagon  125.000      2.7      Diesel
# 8        Renault   10799.0      vagon  120.625      1.5      Diesel
# 9     Volkswagen    1400.0      other  132.500      1.8         Gas
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7
# 4          yes  2011         Rav 4
# ...
