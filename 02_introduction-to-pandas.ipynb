# %%
import pandas as pd

# %% [markdown]
# ## 2 main datatypes

# %%
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1 dimentional

# %%
colours = pd.Series(["Red", "Blue", "White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# DataFrame = 2 dimentional
car_data = pd.DataFrame({"Car make": series, "Colour": colours})
car_data
# Out:
#   Car make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %% [markdown]
# ## Impor/Export Data

# %%
# Import data
car_sales = pd.read_csv("car_sales.csv")

# %%
car_sales
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# 1             yes  1999       Sprinter 212
# 2             yes  2003              S 500
# 3             yes  2007                 Q7
# 4             yes  2011              Rav 4
# ...           ...   ...                ...
# 4340          yes  2014              S 350
# 4341          yes  1999                535
# 4342          yes  1985                520
# 4343          yes  2014            Corolla
# 4344          yes  2013  T5 (Transporter)
#
# [4345 rows x 9 columns]

# %%
# Exporting a dataframe
car_sales.to_csv("exported_car_sales.csv", index = False)

# %%
exported_car_sales = pd.read_csv("exported_car_sales.csv")
exported_car_sales
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# 1             yes  1999       Sprinter 212
# 2             yes  2003              S 500
# 3             yes  2007                 Q7
# 4             yes  2011              Rav 4
# ...           ...   ...                ...
# 4340          yes  2014              S 350
# 4341          yes  1999                535
# 4342          yes  1985                520
# 4343          yes  2014            Corolla
# 4344          yes  2013  T5 (Transporter)
#
# [4345 rows x 9 columns]

# %% [markdown]
# ## Describe data

# %%
# Attribute
car_sales.dtypes

# Function
# car_sales.to_csv()
# Out:
# Brand            object
# Price           float64
# Body             object
# Mileage           int64
# EngineV         float64
# Engine Type      object
# Registration     object
# Year              int64
# Model            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Brand', 'Price', 'Body', 'Mileage', 'EngineV', 'Engine Type',
#        'Registration', 'Year', 'Model'],
#       dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Brand', 'Price', 'Body', 'Mileage', 'EngineV', 'Engine Type',
#        'Registration', 'Year', 'Model'],
#       dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=4345, step=1)

# %%
car_sales.describe()
# Out:
#                Price      Mileage      EngineV         Year
# count    4173.000000  4345.000000  4195.000000  4345.000000
# mean    19418.746935   161.237284     2.790734  2006.550058
# std     25584.242620   105.705797     5.066437     6.719097
# min       600.000000     0.000000     0.600000  1969.000000
# 25%      6999.000000    86.000000     1.800000  2003.000000
# 50%     11500.000000   155.000000     2.200000  2008.000000
# 75%     21700.000000   230.000000     3.000000  2012.000000
# max    300000.000000   980.000000    99.990000  2016.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4345 entries, 0 to 4344
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         4345 non-null   object
#  1   Price         4173 non-null   float64
#  2   Body          4345 non-null   object
#  3   Mileage       4345 non-null   int64
#  4   EngineV       4195 non-null   float64
#  5   Engine Type   4345 non-null   object
#  6   Registration  4345 non-null   object
#  7   Year          4345 non-null   int64
#  8   Model         4345 non-null   object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 305.6+ KB

# %%
car_sales.mean(numeric_only=True)
# Out:
# Price      19418.746935
# Mileage      161.237284
# EngineV        2.790734
# Year        2006.550058
# dtype: float64

# %%
# Calculate any mean
car_prices = pd.Series([3000, 1500, 110505])
car_prices.mean()
# Out:
# 38335.0

# %%
car_sales["Price"].sum()
# Out:
# 81034430.96000001

# %%
len(car_sales)
# Out:
# 4345

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head()
# Out:
#            Brand    Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW   4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz   7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz  13300.0      sedan      358      5.0         Gas
# 3           Audi  23000.0  crossover      240      4.2      Petrol
# 4         Toyota  18300.0  crossover      120      2.0      Petrol
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7
# 4          yes  2011         Rav 4

# %%
car_sales.head(10)
# Out:
#            Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW    4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3           Audi   23000.0  crossover      240      4.2      Petrol
# 4         Toyota   18300.0  crossover      120      2.0      Petrol
# 5  Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 6            BMW    6100.0      sedan      438      2.0         Gas
# 7           Audi   14200.0      vagon      200      2.7      Diesel
# 8        Renault   10799.0      vagon      193      1.5      Diesel
# 9     Volkswagen    1400.0      other      212      1.8         Gas
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7
# 4          yes  2011         Rav 4
# 5          yes  2016        GLS 63
# 6          yes  1997           320
# 7          yes  2006            A6
# 8          yes  2012        Megane
# 9           no  1999       Golf IV

# %%
car_sales.tail()
# Out:
#               Brand     Price   Body  Mileage  EngineV Engine Type  \
# 4340  Mercedes-Benz  125000.0  sedan        9      3.0      Diesel
# 4341            BMW    6500.0  sedan        1      3.5      Petrol
# 4342            BMW    8000.0  sedan      194      2.0      Petrol
# 4343         Toyota   14200.0  sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0    van      124      2.0      Diesel
#
#      Registration  Year              Model
# 4340          yes  2014              S 350
# 4341          yes  1999                535
# 4342          yes  1985                520
# 4343          yes  2014            Corolla
# 4344          yes  2013  T5 (Transporter)

# %%
# .lock & .iloc
animals = pd.Series(["cat", "dogs", "bird", "panda", "snake"],
                  index = [0, 3, 9, 8, 3])

# %%
animals
# Out:
# 0      cat
# 3     dogs
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
#.lock refers to index
animals.loc[3]
# Out:
# 3     dogs
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales.loc[3]
# Out:
# Brand                Audi
# Price             23000.0
# Body            crossover
# Mileage               240
# EngineV               4.2
# Engine Type        Petrol
# Registration          yes
# Year                 2007
# Model                  Q7
# Name: 3, dtype: object

# %%
# .iloc refers to position
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales.iloc[3]
# Out:
# Brand                Audi
# Price             23000.0
# Body            crossover
# Mileage               240
# EngineV               4.2
# Engine Type        Petrol
# Registration          yes
# Year                 2007
# Model                  Q7
# Name: 3, dtype: object

# %%
car_sales.head()
# Out:
#            Brand    Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW   4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz   7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz  13300.0      sedan      358      5.0         Gas
# 3           Audi  23000.0  crossover      240      4.2      Petrol
# 4         Toyota  18300.0  crossover      120      2.0      Petrol
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7
# 4          yes  2011         Rav 4

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3    dogs
# 9    bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#            Brand    Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW   4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz   7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz  13300.0      sedan      358      5.0         Gas
# 3           Audi  23000.0  crossover      240      4.2      Petrol
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7

# %%
car_sales["Brand"]
# Out:
# 0                 BMW
# 1       Mercedes-Benz
# 2       Mercedes-Benz
# 3                Audi
# 4              Toyota
#             ...
# 4340    Mercedes-Benz
# 4341              BMW
# 4342              BMW
# 4343           Toyota
# 4344       Volkswagen
# Name: Brand, Length: 4345, dtype: object

# %%
car_sales.Brand
# Out:
# 0                 BMW
# 1       Mercedes-Benz
# 2       Mercedes-Benz
# 3                Audi
# 4              Toyota
#             ...
# 4340    Mercedes-Benz
# 4341              BMW
# 4342              BMW
# 4343           Toyota
# 4344       Volkswagen
# Name: Brand, Length: 4345, dtype: object

# %%
car_sales["Engine Type"]
# Out:
# 0       Petrol
# 1       Diesel
# 2          Gas
# 3       Petrol
# 4       Petrol
#          ...
# 4340    Diesel
# 4341    Petrol
# 4342    Petrol
# 4343    Petrol
# 4344    Diesel
# Name: Engine Type, Length: 4345, dtype: object

# %%
car_sales[car_sales["Brand"] == "BMW"]
# Out:
#      Brand    Price       Body  Mileage  EngineV Engine Type Registration  \
# 0      BMW   4200.0      sedan      277      2.0      Petrol          yes
# 6      BMW   6100.0      sedan      438      2.0         Gas          yes
# 16     BMW   2990.0      other      203      2.0      Petrol           no
# 31     BMW  21500.0      other       72      3.0      Petrol          yes
# 33     BMW  28500.0  crossover      160      4.8         Gas          yes
# ...    ...      ...        ...      ...      ...         ...          ...
# 4331   BMW  45000.0  crossover       80      3.0      Petrol          yes
# 4334   BMW  12090.0      hatch      145      1.6      Petrol          yes
# 4335   BMW  27900.0      sedan       38      2.0      Petrol          yes
# 4341   BMW   6500.0      sedan        1      3.5      Petrol          yes
# 4342   BMW   8000.0      sedan      194      2.0      Petrol          yes
#
#       Year Model
# 0     1991   320
# 6     1997   320
# 16    2001   318
# 31    2007    Z4
# 33    2008    X5
# ...    ...   ...
# 4331  2011    X6
# 4334  2010   116
# 4335  2013   320
# 4341  1999   535
# 4342  1985   520
#
# [694 rows x 9 columns]

# %%
car_sales[car_sales["Year"] > 2010]
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# 5     Mercedes-Benz  199999.0  crossover        0      5.5      Petrol
# 8           Renault   10799.0      vagon      193      1.5      Diesel
# 10          Renault   11950.0      vagon      177      1.5      Diesel
# 15          Renault    8600.0      hatch       84      1.5      Diesel
# ...             ...       ...        ...      ...      ...         ...
# 4335            BMW   27900.0      sedan       38      2.0      Petrol
# 4339         Toyota   17900.0      sedan       35      1.6      Petrol
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year              Model
# 4             yes  2011              Rav 4
# 5             yes  2016             GLS 63
# 8             yes  2012             Megane
# 10            yes  2011             Megane
# 15            yes  2012               Clio
# ...           ...   ...                ...
# 4335          yes  2013                320
# 4339          yes  2014            Corolla
# 4340          yes  2014              S 350
# 4343          yes  2014            Corolla
# 4344          yes  2013  T5 (Transporter)
#
# [1482 rows x 9 columns]

# %%
car_sales[car_sales["Year"] > 2015]
# Out:
#               Brand      Price       Body  Mileage  EngineV Engine Type  \
# 5     Mercedes-Benz  199999.00  crossover        0     5.50      Petrol
# 20           Toyota   38233.00      other        0     2.40      Diesel
# 29    Mercedes-Benz        NaN  crossover        0     4.60      Petrol
# 37              BMW   67500.00  crossover        1     2.50      Diesel
# 55    Mercedes-Benz        NaN  crossover        0     3.00      Diesel
# ...             ...        ...        ...      ...      ...         ...
# 4274  Mercedes-Benz  109999.00  crossover        0     2.98      Diesel
# 4277  Mercedes-Benz  111999.00  crossover        0     3.00      Diesel
# 4289         Toyota   17394.09      hatch        0     1.33      Petrol
# 4322         Toyota  100000.00  crossover        0     4.50      Diesel
# 4327           Audi   80999.00  crossover        0     3.00      Diesel
#
#      Registration  Year             Model
# 5             yes  2016            GLS 63
# 20            yes  2016             Hilux
# 29            yes  2016           GLS 500
# 37            yes  2016                X5
# 55            yes  2016           GLS 350
# ...           ...   ...               ...
# 4274          yes  2016           GLS 350
# 4277          yes  2016            GL 350
# 4289          yes  2016             Yaris
# 4322          yes  2016  Land Cruiser 200
# 4327          yes  2016                Q7
#
# [258 rows x 9 columns]

# %%
pd.crosstab(car_sales["Brand"], car_sales["Body"])
# Out:
# Body           crossover  hatch  other  sedan  vagon  van
# Brand
# Audi                  77     19     35    217    108    1
# BMW                  191     12     60    389     42    0
# Mercedes-Benz        168     23    141    385     22  182
# Mitsubishi           137     19     26    129      8    8
# Renault               19     41     35     59    112  203
# Toyota               223     59     37    201     13    8
# Volkswagen            86    112     99    269     97  273

# %%
# group by
car_sales.groupby(["Brand"]).mean("Price")
# Out:
#                       Price     Mileage   EngineV         Year
# Brand
# Audi           18489.633484  179.927790  2.647494  2004.800875
# BMW            23525.368087  171.759366  3.203870  2005.259366
# Mercedes-Benz  30608.048122  172.754615  3.289193  2006.387622
# Mitsubishi     11295.713003  140.590214  2.289389  2006.321101
# Renault         8035.127018  156.827292  2.695044  2008.270789
# Toyota         22591.220287  116.500924  2.765814  2008.508318
# Volkswagen     13125.267930  168.257479  2.301499  2006.606838

# %%
# if plot is not showing up run the following line
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Mileage"].plot()
# Out:
# <Axes: >

# %%
car_sales["Year"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Mainpulating Data

# %%
car_sales["Brand"].str.lower()
# Out:
# 0                 bmw
# 1       mercedes-benz
# 2       mercedes-benz
# 3                audi
# 4              toyota
#             ...
# 4340    mercedes-benz
# 4341              bmw
# 4342              bmw
# 4343           toyota
# 4344       volkswagen
# Name: Brand, Length: 4345, dtype: object

# %%
car_sales
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# 1             yes  1999       Sprinter 212
# 2             yes  2003              S 500
# 3             yes  2007                 Q7
# 4             yes  2011              Rav 4
# ...           ...   ...                ...
# 4340          yes  2014              S 350
# 4341          yes  1999                535
# 4342          yes  1985                520
# 4343          yes  2014            Corolla
# 4344          yes  2013  T5 (Transporter)
#
# [4345 rows x 9 columns]

# %%
car_sales["Brand"] = car_sales["Brand"].str.lower()

# %%
car_sales
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               bmw    4200.0      sedan      277      2.0      Petrol
# 1     mercedes-benz    7900.0        van      427      2.9      Diesel
# 2     mercedes-benz   13300.0      sedan      358      5.0         Gas
# 3              audi   23000.0  crossover      240      4.2      Petrol
# 4            toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  mercedes-benz  125000.0      sedan        9      3.0      Diesel
# 4341            bmw    6500.0      sedan        1      3.5      Petrol
# 4342            bmw    8000.0      sedan      194      2.0      Petrol
# 4343         toyota   14200.0      sedan       31      NaN      Petrol
# 4344     volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# 1             yes  1999       Sprinter 212
# 2             yes  2003              S 500
# 3             yes  2007                 Q7
# 4             yes  2011              Rav 4
# ...           ...   ...                ...
# 4340          yes  2014              S 350
# 4341          yes  1999                535
# 4342          yes  1985                520
# 4343          yes  2014            Corolla
# 4344          yes  2013  T5 (Transporter)
#
# [4345 rows x 9 columns]

# %%
car_sales_missing = pd.read_csv("car_sales_with_missing_data.csv")

# %%
car_sales_missing
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi       NaN  crossover      240      4.2      Petrol
# 4               NaN   18300.0  crossover      120      2.0         NaN
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration    Year              Model
# 0             yes  1991.0                320
# 1             yes  1999.0       Sprinter 212
# 2             yes  2003.0              S 500
# 3             yes  2007.0                 Q7
# 4             yes  2011.0              Rav 4
# ...           ...     ...                ...
# 4340          yes  2014.0              S 350
# 4341          yes  1999.0                535
# 4342          yes  1985.0                520
# 4343          yes  2014.0            Corolla
# 4344          yes  2013.0  T5 (Transporter)
#
# [4345 rows x 9 columns]

# %%
car_sales_missing["Price"].fillna(car_sales_missing["Price"].mean())
# Out:
# 0         4200.000000
# 1         7900.000000
# 2        13300.000000
# 3        19421.518216
# 4        18300.000000
#             ...
# 4340    125000.000000
# 4341      6500.000000
# 4342      8000.000000
# 4343     14200.000000
# 4344     13500.000000
# Name: Price, Length: 4345, dtype: float64

# %%
car_sales_missing
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi       NaN  crossover      240      4.2      Petrol
# 4               NaN   18300.0  crossover      120      2.0         NaN
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration    Year              Model
# 0             yes  1991.0                320
# 1             yes  1999.0       Sprinter 212
# 2             yes  2003.0              S 500
# 3             yes  2007.0                 Q7
# 4             yes  2011.0              Rav 4
# ...           ...     ...                ...
# 4340          yes  2014.0              S 350
# 4341          yes  1999.0                535
# 4342          yes  1985.0                520
# 4343          yes  2014.0            Corolla
# 4344          yes  2013.0  T5 (Transporter)
#
# [4345 rows x 9 columns]

# %%
car_sales_missing["Price"].fillna(car_sales_missing["Price"].mean(),
                                 inplace=True)

# %%
car_sales_missing.head(15)
# Out:
#             Brand          Price       Body  Mileage  EngineV Engine Type  \
# 0             BMW    4200.000000      sedan      277     2.00      Petrol
# 1   Mercedes-Benz    7900.000000        van      427     2.90      Diesel
# 2   Mercedes-Benz   13300.000000      sedan      358     5.00         Gas
# 3            Audi   19421.518216  crossover      240     4.20      Petrol
# 4             NaN   18300.000000  crossover      120     2.00         NaN
# 5   Mercedes-Benz  199999.000000  crossover        0     5.50      Petrol
# 6             BMW    6100.000000      sedan      438     2.00         Gas
# 7            Audi   19421.518216      vagon      200     2.70      Diesel
# 8         Renault   10799.000000      vagon      193     1.50         NaN
# 9      Volkswagen    1400.000000      other      212     1.80         Gas
# 10            NaN   11950.000000      vagon      177     1.50      Diesel
# 11        Renault    2500.000000      sedan      260     1.79      Petrol
# 12           Audi   19421.518216      vagon      165     2.70         Gas
# 13     Volkswagen   10500.000000      sedan      100     1.80      Petrol
# 14         Toyota   16000.000000  crossover      250     4.70         Gas
#
#    Registration    Year             Model
# 0           yes  1991.0               320
# 1           yes  1999.0      Sprinter 212
# 2           yes  2003.0             S 500
# 3           yes  2007.0                Q7
# 4           yes  2011.0             Rav 4
# 5           yes  2016.0            GLS 63
# 6           yes  1997.0               320
# 7           yes  2006.0                A6
# 8           yes  2012.0            Megane
# 9            no  1999.0           Golf IV
# 10          yes  2011.0            Megane
# 11          yes  1994.0                19
# 12          yes     NaN        A6 Allroad
# 13          yes  2008.0         Passat B6
# 14          yes  2001.0  Land Cruiser 100

# %%
car_sales_missing.head(15)
# Out:
#             Brand          Price       Body  Mileage  EngineV Engine Type  \
# 0             BMW    4200.000000      sedan      277     2.00      Petrol
# 1   Mercedes-Benz    7900.000000        van      427     2.90      Diesel
# 2   Mercedes-Benz   13300.000000      sedan      358     5.00         Gas
# 3            Audi   19421.518216  crossover      240     4.20      Petrol
# 4             NaN   18300.000000  crossover      120     2.00         NaN
# 5   Mercedes-Benz  199999.000000  crossover        0     5.50      Petrol
# 6             BMW    6100.000000      sedan      438     2.00         Gas
# 7            Audi   19421.518216      vagon      200     2.70      Diesel
# 8         Renault   10799.000000      vagon      193     1.50         NaN
# 9      Volkswagen    1400.000000      other      212     1.80         Gas
# 10            NaN   11950.000000      vagon      177     1.50      Diesel
# 11        Renault    2500.000000      sedan      260     1.79      Petrol
# 12           Audi   19421.518216      vagon      165     2.70         Gas
# 13     Volkswagen   10500.000000      sedan      100     1.80      Petrol
# 14         Toyota   16000.000000  crossover      250     4.70         Gas
#
#    Registration    Year             Model
# 0           yes  1991.0               320
# 1           yes  1999.0      Sprinter 212
# 2           yes  2003.0             S 500
# 3           yes  2007.0                Q7
# 4           yes  2011.0             Rav 4
# 5           yes  2016.0            GLS 63
# 6           yes  1997.0               320
# 7           yes  2006.0                A6
# 8           yes  2012.0            Megane
# 9            no  1999.0           Golf IV
# 10          yes  2011.0            Megane
# 11          yes  1994.0                19
# 12          yes     NaN        A6 Allroad
# 13          yes  2008.0         Passat B6
# 14          yes  2001.0  Land Cruiser 100

# %%
car_sales_missing.dropna()
# Out:
#               Brand          Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.000000      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.000000        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.000000      sedan      358      5.0         Gas
# 3              Audi   19421.518216  crossover      240      4.2      Petrol
# 5     Mercedes-Benz  199999.000000  crossover        0      5.5      Petrol
# ...             ...            ...        ...      ...      ...         ...
# 4339         Toyota   17900.000000      sedan       35      1.6      Petrol
# 4340  Mercedes-Benz  125000.000000      sedan        9      3.0      Diesel
# 4341            BMW    6500.000000      sedan        1      3.5      Petrol
# 4342            BMW    8000.000000      sedan      194      2.0      Petrol
# 4344     Volkswagen   13500.000000        van      124      2.0      Diesel
#
#      Registration    Year              Model
# 0             yes  1991.0                320
# 1             yes  1999.0       Sprinter 212
# 2             yes  2003.0              S 500
# 3             yes  2007.0                 Q7
# 5             yes  2016.0             GLS 63
# ...           ...     ...                ...
# 4339          yes  2014.0            Corolla
# 4340          yes  2014.0              S 350
# 4341          yes  1999.0                535
# 4342          yes  1985.0                520
# 4344          yes  2013.0  T5 (Transporter)
#
# [4188 rows x 9 columns]

# %%
car_sales_missing.head(15)
# Out:
#             Brand          Price       Body  Mileage  EngineV Engine Type  \
# 0             BMW    4200.000000      sedan      277     2.00      Petrol
# 1   Mercedes-Benz    7900.000000        van      427     2.90      Diesel
# 2   Mercedes-Benz   13300.000000      sedan      358     5.00         Gas
# 3            Audi   19421.518216  crossover      240     4.20      Petrol
# 4             NaN   18300.000000  crossover      120     2.00         NaN
# 5   Mercedes-Benz  199999.000000  crossover        0     5.50      Petrol
# 6             BMW    6100.000000      sedan      438     2.00         Gas
# 7            Audi   19421.518216      vagon      200     2.70      Diesel
# 8         Renault   10799.000000      vagon      193     1.50         NaN
# 9      Volkswagen    1400.000000      other      212     1.80         Gas
# 10            NaN   11950.000000      vagon      177     1.50      Diesel
# 11        Renault    2500.000000      sedan      260     1.79      Petrol
# 12           Audi   19421.518216      vagon      165     2.70         Gas
# 13     Volkswagen   10500.000000      sedan      100     1.80      Petrol
# 14         Toyota   16000.000000  crossover      250     4.70         Gas
#
#    Registration    Year             Model
# 0           yes  1991.0               320
# 1           yes  1999.0      Sprinter 212
# 2           yes  2003.0             S 500
# 3           yes  2007.0                Q7
# 4           yes  2011.0             Rav 4
# 5           yes  2016.0            GLS 63
# 6           yes  1997.0               320
# 7           yes  2006.0                A6
# 8           yes  2012.0            Megane
# 9            no  1999.0           Golf IV
# 10          yes  2011.0            Megane
# 11          yes  1994.0                19
# 12          yes     NaN        A6 Allroad
# 13          yes  2008.0         Passat B6
# 14          yes  2001.0  Land Cruiser 100

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing.head(15)
# Out:
#             Brand          Price       Body  Mileage  EngineV Engine Type  \
# 0             BMW    4200.000000      sedan      277     2.00      Petrol
# 1   Mercedes-Benz    7900.000000        van      427     2.90      Diesel
# 2   Mercedes-Benz   13300.000000      sedan      358     5.00         Gas
# 3            Audi   19421.518216  crossover      240     4.20      Petrol
# 5   Mercedes-Benz  199999.000000  crossover        0     5.50      Petrol
# 6             BMW    6100.000000      sedan      438     2.00         Gas
# 7            Audi   19421.518216      vagon      200     2.70      Diesel
# 9      Volkswagen    1400.000000      other      212     1.80         Gas
# 11        Renault    2500.000000      sedan      260     1.79      Petrol
# 13     Volkswagen   10500.000000      sedan      100     1.80      Petrol
# 14         Toyota   16000.000000  crossover      250     4.70         Gas
# 15        Renault    8600.000000      hatch       84     1.50      Diesel
# 16            BMW    2990.000000      other      203     2.00      Petrol
# 17  Mercedes-Benz   19421.518216        van      240     2.20      Diesel
# 18         Toyota   26500.000000  crossover       21     2.00      Petrol
#
#    Registration    Year             Model
# 0           yes  1991.0               320
# 1           yes  1999.0      Sprinter 212
# 2           yes  2003.0             S 500
# 3           yes  2007.0                Q7
# 5           yes  2016.0            GLS 63
# 6           yes  1997.0               320
# 7           yes  2006.0                A6
# 9            no  1999.0           Golf IV
# 11          yes  1994.0                19
# 13          yes  2008.0         Passat B6
# 14          yes  2001.0  Land Cruiser 100
# 15          yes  2012.0              Clio
# 16           no  2001.0               318
# 17          yes  2007.0              Vito
# 18          yes  2013.0             Rav 4

# %%
# Column from series
seats_column = pd.Series([5, 5, 5, 5, 5])

# New calumn called seats
car_sales["Seats"] = seats_column

# %%
car_sales.head(15)
# Out:
#             Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0             bmw    4200.0      sedan      277     2.00      Petrol
# 1   mercedes-benz    7900.0        van      427     2.90      Diesel
# 2   mercedes-benz   13300.0      sedan      358     5.00         Gas
# 3            audi   23000.0  crossover      240     4.20      Petrol
# 4          toyota   18300.0  crossover      120     2.00      Petrol
# 5   mercedes-benz  199999.0  crossover        0     5.50      Petrol
# 6             bmw    6100.0      sedan      438     2.00         Gas
# 7            audi   14200.0      vagon      200     2.70      Diesel
# 8         renault   10799.0      vagon      193     1.50      Diesel
# 9      volkswagen    1400.0      other      212     1.80         Gas
# 10        renault   11950.0      vagon      177     1.50      Diesel
# 11        renault    2500.0      sedan      260     1.79      Petrol
# 12           audi    9500.0      vagon      165     2.70         Gas
# 13     volkswagen   10500.0      sedan      100     1.80      Petrol
# 14         toyota   16000.0  crossover      250     4.70         Gas
#
#    Registration  Year             Model  Seats
# 0           yes  1991               320    5.0
# 1           yes  1999      Sprinter 212    5.0
# 2           yes  2003             S 500    5.0
# 3           yes  2007                Q7    5.0
# 4           yes  2011             Rav 4    5.0
# 5           yes  2016            GLS 63    NaN
# 6           yes  1997               320    NaN
# 7           yes  2006                A6    NaN
# 8           yes  2012            Megane    NaN
# 9            no  1999           Golf IV    NaN
# 10          yes  2011            Megane    NaN
# 11          yes  1994                19    NaN
# 12          yes  2003        A6 Allroad    NaN
# 13          yes  2008         Passat B6    NaN
# 14          yes  2001  Land Cruiser 100    NaN

# %%
car_sales["Seats"].fillna(5, inplace=True)

# %%
car_sales.head(15)
# Out:
#             Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0             bmw    4200.0      sedan      277     2.00      Petrol
# 1   mercedes-benz    7900.0        van      427     2.90      Diesel
# 2   mercedes-benz   13300.0      sedan      358     5.00         Gas
# 3            audi   23000.0  crossover      240     4.20      Petrol
# 4          toyota   18300.0  crossover      120     2.00      Petrol
# 5   mercedes-benz  199999.0  crossover        0     5.50      Petrol
# 6             bmw    6100.0      sedan      438     2.00         Gas
# 7            audi   14200.0      vagon      200     2.70      Diesel
# 8         renault   10799.0      vagon      193     1.50      Diesel
# 9      volkswagen    1400.0      other      212     1.80         Gas
# 10        renault   11950.0      vagon      177     1.50      Diesel
# 11        renault    2500.0      sedan      260     1.79      Petrol
# 12           audi    9500.0      vagon      165     2.70         Gas
# 13     volkswagen   10500.0      sedan      100     1.80      Petrol
# 14         toyota   16000.0  crossover      250     4.70         Gas
#
#    Registration  Year             Model  Seats
# 0           yes  1991               320    5.0
# 1           yes  1999      Sprinter 212    5.0
# 2           yes  2003             S 500    5.0
# 3           yes  2007                Q7    5.0
# 4           yes  2011             Rav 4    5.0
# 5           yes  2016            GLS 63    5.0
# 6           yes  1997               320    5.0
# 7           yes  2006                A6    5.0
# 8           yes  2012            Megane    5.0
# 9            no  1999           Golf IV    5.0
# 10          yes  2011            Megane    5.0
# 11          yes  1994                19    5.0
# 12          yes  2003        A6 Allroad    5.0
# 13          yes  2008         Passat B6    5.0
# 14          yes  2001  Land Cruiser 100    5.0

# %%
# Column from Python list
fuel_economy = [7.5, 9.2, 5.0, 9.6]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# If we want to create from Python list 
# the lenght of list should be same as the number of rows 
# of dataframe
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 3
#       1 # Column from Python list
#       2 fuel_economy = [7.5, 9.2, 5.0, 9.6]
# ----> 3 car_sales["Fuel per 100KM"] = fuel_economy
#       4 car_sales
#
# File ~/Projects/personal/learn-ml/env/lib/python3.11/site-packages/pandas/core/frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File ~/Projects/personal/learn-ml/env/lib/python3.11/site-packages/pandas/core/frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
#    4177         key in self.columns
#    4178         and value.ndim == 1
#    4179         and not is_extension_array_dtype(value)
#    4180     ):
#    4181         # broadcast across multiple columns if necessary
#    4182         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/Projects/personal/learn-ml/env/lib/python3.11/site-packages/pandas/core/frame.py:4915, in DataFrame._sanitize_column(self, value)
#    4912     return _reindex_for_setitem(Series(value), self.index)
#    4914 if is_list_like(value):
# -> 4915     com.require_length_match(value, self.index)
#    4916 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~/Projects/personal/learn-ml/env/lib/python3.11/site-packages/pandas/core/common.py:571, in require_length_match(data, index)
#     567 """
#     568 Check the length of data matches the length of the index.
#     569 """
#     570 if len(data) != len(index):
# --> 571     raise ValueError(
#     572         "Length of values "
#     573         f"({len(data)}) "
#     574         "does not match length of index "
#     575         f"({len(index)})"
#     576     )
#
# ValueError: Length of values (4) does not match length of index (4345)

# %%
car_sales["Fuel per 100KM"] = pd.Series([7.5, 9.2, 5.0, 9.6])
car_sales
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               bmw    4200.0      sedan      277      2.0      Petrol
# 1     mercedes-benz    7900.0        van      427      2.9      Diesel
# 2     mercedes-benz   13300.0      sedan      358      5.0         Gas
# 3              audi   23000.0  crossover      240      4.2      Petrol
# 4            toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  mercedes-benz  125000.0      sedan        9      3.0      Diesel
# 4341            bmw    6500.0      sedan        1      3.5      Petrol
# 4342            bmw    8000.0      sedan      194      2.0      Petrol
# 4343         toyota   14200.0      sedan       31      NaN      Petrol
# 4344     volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year              Model  Seats  Fuel per 100KM
# 0             yes  1991                320    5.0             7.5
# 1             yes  1999       Sprinter 212    5.0             9.2
# 2             yes  2003              S 500    5.0             5.0
# 3             yes  2007                 Q7    5.0             9.6
# 4             yes  2011              Rav 4    5.0             NaN
# ...           ...   ...                ...    ...             ...
# 4340          yes  2014              S 350    5.0             NaN
# 4341          yes  1999                535    5.0             NaN
# 4342          yes  1985                520    5.0             NaN
# 4343          yes  2014            Corolla    5.0             NaN
# 4344          yes  2013  T5 (Transporter)     5.0             NaN
#
# [4345 rows x 11 columns]

# %%
car_sales["Number of wheels"] = 4

# %%
car_sales
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               bmw    4200.0      sedan      277      2.0      Petrol
# 1     mercedes-benz    7900.0        van      427      2.9      Diesel
# 2     mercedes-benz   13300.0      sedan      358      5.0         Gas
# 3              audi   23000.0  crossover      240      4.2      Petrol
# 4            toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  mercedes-benz  125000.0      sedan        9      3.0      Diesel
# 4341            bmw    6500.0      sedan        1      3.5      Petrol
# 4342            bmw    8000.0      sedan      194      2.0      Petrol
# 4343         toyota   14200.0      sedan       31      NaN      Petrol
# 4344     volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year              Model  Seats  Fuel per 100KM  \
# 0             yes  1991                320    5.0             7.5
# 1             yes  1999       Sprinter 212    5.0             9.2
# 2             yes  2003              S 500    5.0             5.0
# 3             yes  2007                 Q7    5.0             9.6
# 4             yes  2011              Rav 4    5.0             NaN
# ...           ...   ...                ...    ...             ...
# 4340          yes  2014              S 350    5.0             NaN
# 4341          yes  1999                535    5.0             NaN
# 4342          yes  1985                520    5.0             NaN
# 4343          yes  2014            Corolla    5.0             NaN
# 4344          yes  2013  T5 (Transporter)     5.0             NaN
#
#       Number of wheels
# 0                    4
# 1                    4
# 2                    4
# 3                    4
# 4                    4
# ...                ...
# 4340                 4
# 4341                 4
# 4342                 4
# 4343                 4
# 4344                 4
#
# [4345 rows x 12 columns]

# %%
car_sales["Passed road safety"] = True

# %%
car_sales.dtypes
# Out:
# Brand                  object
# Price                 float64
# Body                   object
# Mileage                 int64
# EngineV               float64
# Engine Type            object
# Registration           object
# Year                    int64
# Model                  object
# Seats                 float64
# Fuel per 100KM        float64
# Number of wheels        int64
# Passed road safety       bool
# dtype: object

# %%
car_sales = car_sales.drop("Fuel per 100KM", axis = 1) # axis = 1 means column

# %%
car_sales
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               bmw    4200.0      sedan      277      2.0      Petrol
# 1     mercedes-benz    7900.0        van      427      2.9      Diesel
# 2     mercedes-benz   13300.0      sedan      358      5.0         Gas
# 3              audi   23000.0  crossover      240      4.2      Petrol
# 4            toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  mercedes-benz  125000.0      sedan        9      3.0      Diesel
# 4341            bmw    6500.0      sedan        1      3.5      Petrol
# 4342            bmw    8000.0      sedan      194      2.0      Petrol
# 4343         toyota   14200.0      sedan       31      NaN      Petrol
# 4344     volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year              Model  Seats  Number of wheels  \
# 0             yes  1991                320    5.0                 4
# 1             yes  1999       Sprinter 212    5.0                 4
# 2             yes  2003              S 500    5.0                 4
# 3             yes  2007                 Q7    5.0                 4
# 4             yes  2011              Rav 4    5.0                 4
# ...           ...   ...                ...    ...               ...
# 4340          yes  2014              S 350    5.0                 4
# 4341          yes  1999                535    5.0                 4
# 4342          yes  1985                520    5.0                 4
# 4343          yes  2014            Corolla    5.0                 4
# 4344          yes  2013  T5 (Transporter)     5.0                 4
#
#       Passed road safety
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ...                  ...
# 4340                True
# 4341                True
# 4342                True
# 4343                True
# 4344                True
#
# [4345 rows x 12 columns]
